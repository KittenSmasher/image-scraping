# %%
import pandas as pd

df = pd.read_csv('Music Info.csv')
df.head()
# Out:
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...  09ZQ5TmUG8TSL56n0knqrj
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...  06UfBBDISthj1ZJAtX4xjj
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...  0keNu0t0tqsWtExGM3nT1D
# 3  https://p.scdn.co/mp3-preview/399c401370438be4...  0ancVQ9wEcHVd0RrGICTE4
# 4  https://p.scdn.co/mp3-preview/e7eb60e9466bc3a2...  01QoK9DA7VTeTSE3MNzp4I
#
#                                                 tags genre  year  duration_ms  \
# 0  rock, alternative, indie, alternative_rock, in...   NaN  2004       222200
# ...

# %%
with open('track_id.txt', 'r') as file:
    track_ids = [line.strip() for line in file]
    
filtered = df[df['track_id'].isin(track_ids)]
filtered.head()
# Out:
#                track_id                   name                 artist  \
# 83   TRPSVTL128F936017F       Sultans of Swing           Dire Straits
# 169  TRHHSUX128F932E546          Bodysnatchers              Radiohead
# 226  TRFOBPI128F42734B9         The Unforgiven              Metallica
# 278  TRQUFVD128F4236831  Walk on the Wild Side               Lou Reed
# 289  TRFNFGI128F930A920                  Today  The Smashing Pumpkins
#
#                                    spotify_preview_url  \
# 83   https://p.scdn.co/mp3-preview/a00a90236f87d059...
# 169  https://p.scdn.co/mp3-preview/f7d0f2aabcc8ba21...
# 226  https://p.scdn.co/mp3-preview/12ea9e15edc7c5ac...
# 278  https://p.scdn.co/mp3-preview/ba3b4fe65d519880...
# 289  https://p.scdn.co/mp3-preview/2250f5fd51839d2e...
#
#                  spotify_id  \
# 83   00C4IJWpY3k2cmo7dHuSs1
# 169  1frWqD5oqa1mukQJKYyzqn
# 226  0BAjUM6V9P9g8rK83hVUTJ
# 278  03c6s6VTKDsCU1R5bclNii
# 289  0GRxGPPrL61m6sl14h9a7Z
#
# ...

# %%
selected = filtered[['track_id', 'spotify_id', 'genre']]
selected.head()
# Out:
#                track_id              spotify_id       genre
# 83   TRPSVTL128F936017F  00C4IJWpY3k2cmo7dHuSs1        Rock
# 169  TRHHSUX128F932E546  1frWqD5oqa1mukQJKYyzqn  Electronic
# 226  TRFOBPI128F42734B9  0BAjUM6V9P9g8rK83hVUTJ       Metal
# 278  TRQUFVD128F4236831  03c6s6VTKDsCU1R5bclNii        Jazz
# 289  TRFNFGI128F930A920  0GRxGPPrL61m6sl14h9a7Z     Country

# %%
selected = selected.sort_values(by='genre')
selected.head()
# Out:
#                  track_id              spotify_id  genre
# 47016  TRCQSGB128F9325176  1HGnml6ufrYuGj5y5tk0pe  Blues
# 23837  TRIVXMR128EF347EC9  0175RdLhdePpj41jHfr8mW  Blues
# 23834  TRONTYT12903CB19C9  00u3IsZKQJXlIIHFgLxbU9  Blues
# 23831  TRKIJDR128F92C2E32  0Jo0gFzUud963rYSsaRTta  Blues
# 23805  TRXCFWD128F9335584  0i1ksGhoLEq9Ah4Z4TclZH  Blues

# %%
selected.value_counts
# Out:
# <bound method DataFrame.value_counts of                  track_id              spotify_id  genre
# 47016  TRCQSGB128F9325176  1HGnml6ufrYuGj5y5tk0pe  Blues
# 23837  TRIVXMR128EF347EC9  0175RdLhdePpj41jHfr8mW  Blues
# 23834  TRONTYT12903CB19C9  00u3IsZKQJXlIIHFgLxbU9  Blues
# 23831  TRKIJDR128F92C2E32  0Jo0gFzUud963rYSsaRTta  Blues
# 23805  TRXCFWD128F9335584  0i1ksGhoLEq9Ah4Z4TclZH  Blues
# ...                   ...                     ...    ...
# 49244  TRIUVGX128F148C9F4  13p9ej7QiZSR3yoLSIxBLS  World
# 49241  TRAULXY128F1452F8E  3Uf7C4YcD6Wzp6gXqmWsRn  World
# 49226  TRIQOSH128F149B901  0q8IPz5YiMnuePivww3GK0  World
# 49315  TRQWUAH128EF346713  0d3QbNg4OCII5uSvpucJ5N  World
# 41575  TRBCSJN128F14541C2  2O14h40U7KwV4hPbsSWsE2  World
#
# [1500 rows x 3 columns]>

# %%
selected.to_csv('filtered_info.csv', index=False)
